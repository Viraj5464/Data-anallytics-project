# %% [markdown]
# # 1. Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Load the dataset - Doctor_Visits

# %%
df = pd.read_csv("DoctorVisits.csv")
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# # 3. Study the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# # 4. Find the columns having any null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # 5. Find the values of each columns

# %%
df['visits'].value_counts()
# Out:
# 0    4141
# 1     782
# 2     174
# 3      30
# 4      24
# 7      12
# 6      12
# 5       9
# 8       5
# 9       1
# Name: visits, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 0.22    1213
# 0.72     822
# 0.19     752
# 0.27     523
# 0.62     316
# 0.67     315
# 0.32     301
# 0.57     273
# 0.52     222
# 0.47     181
# 0.37     146
# 0.42     126
# Name: age, dtype: int64

# %%
df['illness'].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df['income'].value_counts()
# Out:
# 0.25    1195
# 0.90     589
# 0.55     467
# 0.35     462
# 0.65     455
# 0.75     441
# 0.45     400
# 1.10     361
# 0.15     249
# 1.50     215
# 1.30     162
# 0.06      80
# 0.00      79
# 0.01      35
# Name: income, dtype: int64

# %% [markdown]
# # 6. no.of days of reduced activity of male and female due to illness

# %%
df.groupby(['gender','reduced']).mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13328\1883727358.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['gender','reduced']).mean()
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
# ...

# %% [markdown]
# # 7. no.of days of reduced activity based on visits to the doctor

# %%
df.groupby(['visits','reduced']).mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13328\4173938118.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['visits','reduced']).mean()
#                  Unnamed: 0       age    income   illness     health
# visits reduced
# 0      0        3153.906300  0.391186  0.601543  1.164108   0.922975
#        1        2918.697674  0.299612  0.586434  1.906977   1.186047
#        2        2827.158730  0.359365  0.606508  2.190476   1.666667
#        3        2766.600000  0.381667  0.602000  2.433333   1.766667
#        4        2446.550000  0.407500  0.600000  2.600000   2.500000
# ...                     ...       ...       ...       ...        ...
# 7      14        666.142857  0.577143  0.228571  3.285714   2.857143
# ...

# %% [markdown]
# # 8. Find correlation between variables in the dataset

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13328\158644039.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %% [markdown]
# # 9. Check how income of the patient affects no.of visits to the hospital

# %%
plt.figure(figsize=(5,5))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# # 10. analyse the max,min and medium age of visits

# %%
y=list(df.age)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # 11. analyse the max,min and medium income of visits

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # 12. visualize the no.of males and females affected by illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %% [markdown]
# # 13. Visualizing the count of patients having lchronic illness

# %%
sns.histplot(df.age,bins=6)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # 14. visualize the percentage of people getting govt health insurance due to low income and old age and also the percentage of people having privata insurance

# %%
#% of people getting govt Insurance due to low income
label=['yes', 'no']

Y=df[df['freepoor']=='yes']
N=df[df['freepoor']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label,autopct='%1.1f%%')
plt.title("% of people getting govt health Insurance due to low income ")
plt.show()

# %%
#% of people having private Insurance 
Y=df[df['private']=='yes']
N=df[df['private']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label,autopct='%1.1f%%')
plt.title("% of people having private health Insurance")
plt.show()

# %%
#% of people getting govt Insurance due to old age, disability or veteran status
                                    
Y=df[df['freerepat']=='yes']
N = df[df['freerepat']=='no' ]
x = [Y.shape[0], N.shape[0]]
plt.figure(figsize =(5,5))
plt.pie(x, labels=label,autopct='%1.1f%%')
plt.title("% of people getting govt health Insurance due to old age, disability or veteran status ")
plt.show()

# %% [markdown]
# # 15. Visualize the visits percentage having lchronic illness

# %%
label=['yes', 'no']

Y=df[df['lchronic']=='yes']
N=df[df['lchronic']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
colors = [ "#1f77b4","#d62728" ]
plt.pie(x, labels=label,colors=colors,autopct='%1.1f%%')
plt.title("Percenatge of people having lchronic illness")
plt.show()

# %% [markdown]
# # 16. Analyse the visits illness based on  no. of visits

# %%
import seaborn as snb
import matplotlib.pyplot as plt
snb.histplot(df, x="illness", hue="visits",bins=6)
plt.show()

# %% [markdown]
# # 17. Analyse the percentage of visits of people based on their health type

# %%
db=df.groupby('health')['visits'].sum().to_frame().reset_index()
illness = db["health"]
visits = db["visits"]
colors = ["#1f77b4", "#ff7f0e","#2ca02c", "#d62728", "#8c564b","#B2BEB5" ]
plt.pie(visits, labels=illness, colors=colors,autopct='%1.1f%%')
plt.title("Percentage of no.of visits to the hospital based on health")
plt.show()

# %% [markdown]
# # 18. Visualize the relation of age and illness

# %%
db=df.groupby('illness')['age'].sum().to_frame().reset_index()
#creating the bar chart

#Adding the asthetics
fig,ax = plt.subplots()
width = 0.5
ind = np.arange(len(db['age']))
 
ax.barh(ind, db['age'], width, color = "blue")
 


plt.title('Relation between age and illnesss')
plt.xlabel('age')
plt.ylabel('illness')
plt.show()

# %% [markdown]
# # 19. Analysing the income of visits based on health type

# %%
snb.histplot(df, x="income",hue="health",bins=14)
plt.show()

# %% [markdown]
# # 20. Find the gender which has more visits using scatter plot

# %%
plt.figure(figsize=(5,5))
plt.scatter(x='gender',y='visits',data=df)
plt.xlabel('gender')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# # 21. Finding the gender of visits whose has lchronic illness type

# %%
sns.histplot(df, x="lchronic",hue="gender",shrink=.5)
plt.show()
